# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
marvel=pd.read_csv("charcters_stats.csv")

# %%
marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
marvel.shape
# Out:
# (611, 9)

# %%
marvel['Alignment'].value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
marvel[marvel['Alignment']=='good']
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
good=marvel[marvel['Alignment']=="good"]

# %%
good.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %%
good.sort_values(by=['Speed'],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# 295     63      60    343
# 525    100      85    568
# 447     57      56    364

# %%
good.sort_values(by=['Power'],ascending=False).head()
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609        Zatanna      good            75        10     23          28
# 546           Thor      good            69       100     92         100
# 511          Spawn      good            75        60     50          90
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467

# %%
good.sort_values(by=['Strength'],ascending=False).head()
# Out:
#          Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 537  Superman      good           100       100    100         100     94
# 608      Ymir      good            50       100     27         100     83
# 491  She-Hulk      good            69       100     42         100     33
# 251      Goku      good            56       100     75          90    100
# 70   Beyonder      good            88       100     23         100    100
#
#      Combat  Total
# 537      85    579
# 608      28    388
# 491      70    414
# 251     100    521
# 70       56    467

# %%
good.sort_values(by=['Durability'],ascending=False).head()
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 525           Stardust      good            88        85    100         110
# 499      Silver Surfer      good            63       100     84         101
# 417               Nova      good           100        85     67         101
# 361  Martian Manhunter      good           100       100     96         100
# 487        Shadow King      good            75        12     27         100
#
#      Power  Combat  Total
# 525    100      85    568
# 499    100      32    480
# 417    100      85    538
# 361    100      85    581
# 487    100      75    389

# %%
good.sort_values(by=['Intelligence'],ascending=False).head()
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 306          Jean Grey      good           100        80     67         100
# 123         Brainiac 5      good           100        10     23          28
# 433            Phoenix      good           100        80     67         100
# 417               Nova      good           100        85     67         101
#
#      Power  Combat  Total
# 361    100      85    581
# 306    100      70    517
# 123     60      32    253
# 433    100      70    517
# 417    100      85    538

# %%
good.sort_values(by=['Combat'],ascending=False).head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 36         Ares      good            75        82     35          80     62
# 298   Iron Fist      good            75        23     35          42     43
# 597   Wolverine      good            55        32     38         100     44
# 58   Batgirl IV      good            69        12     27          56     42
# 61       Batman      good           100        18     27          42     37
#
#      Combat  Total
# 36      101    435
# 298     100    318
# 597     100    369
# 58      100    306
# 61      100    324

# %%
max_speed_good=good[good['Speed']==100]

# %%
max_speed_good
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 85       Black Bolt      good            75        67    100          84
# 229         Flash I      good            63        10    100          50
# 230        Flash II      good            63        10    100          60
# 231       Flash III      good            63        10    100          60
# 232        Flash IV      good            63        10    100          32
# 295         Impulse      good            50        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 333          Krypto      good             9        80    100          90
# 418            Nova      good            38        60    100         100
# 447     Quicksilver      good            63        28    100          60
# 525        Stardust      good            88        85    100         110
# 537        Superman      good           100       100    100         100
#
# ...

# %%
min_speed_good=good[good['Speed']==1]

# %%
min_speed_good
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 7        Adam Strange      good             1         1      1           1
# 8           Agent  13      good             1         1      1           1
# 13       Alex Woolsly      good             1         1      1           1
# 15   Allan Quatermain      good             1         1      1           1
# 18     Ando Masahashi      good             1         1      1           1
# ..                ...       ...           ...       ...    ...         ...
# 580            Vulcan      good             1         1      1           1
# 584           Warbird      good             1         1      1           1
# 591       White Queen      good             1         1      1           1
# 595           Wiz Kid      good             1         1      1           1
# 601            Wondra      good             1         1      1           1
#
#      Power  Combat  Total
# 7        0       1      5
# ...

# %%
good_max_power_full=good[good['Power']==100]

# %%
good_max_power_full.shape
# Out:
# (33, 9)

# %%
good_max_power_full
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# 266         Hal Jordan      good            63        90     53          64
# ...

# %%
good_max_power_full.head()
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %%
good_max_power=good.sort_values(by=['Total'],ascending=False)

# %%
plt.figure(figsize=(8,5))
plt.bar(list(good_max_power['Name'])[0:5],list(good_max_power['Total'])[0:5],color=['green','blue','grey','black','red'])
plt.show()

# %%
bad=marvel[marvel['Alignment']=="bad"]

# %%
bad.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
bad.sort_values(by=['Speed'],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610            Zoom       bad            50        10    100          28
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 610     72      28    288
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 242     94      95    579

# %%
bad.sort_values(by=['Intelligence'],ascending=False).head()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 338       Lex Luthor       bad           100        10     12          14
# 336           Leader       bad           100        10     12          14
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
#
#      Power  Combat  Total
# 386    100      28    277
# 338     10      28    174
# 336     58      42    236
# 122     60      75    416
# 194     93      84    429

# %%
bad.sort_values(by=['Total'],ascending=False).head()
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %%
bad_max_power=bad.sort_values(by=['Total'],ascending=False)

# %%
plt.figure(figsize=(10,5))
plt.bar(list(bad_max_power['Name'])[0:5],list(bad_max_power['Total'])[0:5],color=['blue','grey','yellow','red','green'])
plt.show()

# %%
#histogram for speed of superheroes
plt.figure(figsize=(5,7))
plt.hist(good['Speed'])
plt.title("Distribution of Speed")
plt.xlabel("Speed")
plt.show()

# %%
#histogram for combat of superheroes
plt.figure(figsize=(5,7))
plt.hist(good['Combat'])
plt.title("Distribution of Combat")
plt.xlabel("Speed")
plt.show()

# %%
marvel_total=marvel[['Name','Total']]

# %%
marvel_total.head()
# Out:
#           Name  Total
# 0      3-D Man    233
# 1       A-Bomb    316
# 2   Abe Sapien    299
# 3     Abin Sur    406
# 4  Abomination    436
